# %%
import pandas as pd
df = pd.read_csv('./full_dataset.csv')

# %%
df
# Out:
#          Duration  FlowBytesSent  FlowSentRate  FlowBytesReceived  \
# 0       95.081550          62311    655.342703              65358
# 1      122.309318          93828    767.136973             101232
# 2      120.958413          38784    320.639127              38236
# 3      110.501080          61993    561.017141              69757
# 4       54.229891          83641   1542.341289              76804
# ...           ...            ...           ...                ...
# 39609  120.489229          24155    200.474351              39526
# 39610  120.522576          51632    428.401066              32080
# 39611  120.360950          47923    398.160699              88167
# 39612  120.608554          44979    372.933747              86529
# 39613  120.642706          45883    380.321376              89641
#
#        FlowReceivedRate  PacketLengthVariance  PacketLengthStandardDeviation  \
# 0            687.388878           7474.676771                      86.456213
# 1            827.672018          10458.118600                     102.264943
# 2            316.108645           7300.293933                      85.441758
# 3            631.278898           8499.282518                      92.191553
# 4           1416.266907           8052.745751                      89.737092
# ...                 ...                   ...                            ...
# 39609        328.045920          40999.197040                     202.482585
# 39610        266.174198          24846.903090                     157.629005
# 39611        732.521636          33856.106820                     184.000290
# 39612        717.436675          33823.060610                     183.910469
# 39613        743.028758          33324.590930                     182.550242
#
#        PacketLengthMean  PacketLengthMedian  PacketLengthMode  ...  \
# 0            135.673751               102.0                54  ...
# 1            141.245474               114.0                54  ...
# 2            133.715278                89.0                54  ...
# 3            139.123548               114.0                54  ...
# 4            138.913420               114.0               114  ...
# ...                 ...                 ...               ...  ...
# 39609        168.915119               148.0                68  ...
# 39610        195.132867               180.0                68  ...
# 39611        243.017857               257.0                68  ...
# 39612        250.015209               257.0                68  ...
# 39613        258.633588               257.0                68  ...
#
#        PacketTimeCoefficientofVariation  ResponseTimeTimeVariance  \
# 0                              0.574626                  0.001053
# 1                              0.509047                  0.001170
# 2                              0.732636                  0.000785
# 3                              0.646859                  0.000411
# 4                              0.507334                  0.079079
# ...                                 ...                       ...
# 39609                          0.675699                  0.104322
# 39610                          0.514797                  0.179608
# 39611                          0.569166                  0.027457
# 39612                          0.576832                  0.032776
# 39613                          0.595560                  0.015896
#
#        ResponseTimeTimeStandardDeviation  ResponseTimeTimeMean  \
# 0                               0.032457              0.027624
# 1                               0.034200              0.024387
# 2                               0.028021              0.029238
# 3                               0.020274              0.019925
# 4                               0.281209              0.025930
# ...                                  ...                   ...
# 39609                           0.322989              0.184579
# 39610                           0.423802              0.259088
# 39611                           0.165701              0.091486
# 39612                           0.181041              0.090967
# 39613                           0.126080              0.062919
#
#        ResponseTimeTimeMedian  ResponseTimeTimeMode  \
# 0                    0.026854              0.026822
# 1                    0.021043              0.026981
# 2                    0.026922              0.026855
# 3                    0.019268              0.026918
# 4                    0.000046              0.000021
# ...                       ...                   ...
# 39609                0.026514              0.026358
# 39610                0.000587              0.000017
# 39611                0.026495              0.026402
# 39612                0.026498              0.026442
# 39613                0.026488              0.026410
#
#        ResponseTimeTimeSkewFromMedian  ResponseTimeTimeSkewFromMode  \
# 0                            0.071187                      0.024715
# 1                            0.293297                     -0.075845
# 2                            0.248064                      0.085061
# 3                            0.097199                     -0.344926
# 4                            0.276133                      0.092135
# ...                               ...                           ...
# 39609                        1.468147                      0.489865
# 39610                        1.829869                      0.611301
# 39611                        1.176648                      0.392777
# 39612                        1.068310                      0.356412
# 39613                        0.866851                      0.289569
#
#        ResponseTimeTimeCoefficientofVariation  Label
# 0                                    1.174948      0
# 1                                    1.402382      0
# 2                                    0.958348      0
# 3                                    1.017535      0
# 4                                   10.844829      0
# ...                                       ...    ...
# 39609                                1.749867      1
# 39610                                1.635747      1
# 39611                                1.811224      1
# 39612                                1.990176      1
# 39613                                2.003853      1
#
# [39614 rows x 30 columns]

# %%
df = df.drop(['ResponseTimeTimeMedian','ResponseTimeTimeSkewFromMedian'],axis=1)

# %%
X = df.drop(['Label'], axis=1)
y = df['Label']

# %%
X
# Out:
#          Duration  FlowBytesSent  FlowSentRate  FlowBytesReceived  \
# 0       95.081550          62311    655.342703              65358
# 1      122.309318          93828    767.136973             101232
# 2      120.958413          38784    320.639127              38236
# 3      110.501080          61993    561.017141              69757
# 4       54.229891          83641   1542.341289              76804
# ...           ...            ...           ...                ...
# 39609  120.489229          24155    200.474351              39526
# 39610  120.522576          51632    428.401066              32080
# 39611  120.360950          47923    398.160699              88167
# 39612  120.608554          44979    372.933747              86529
# 39613  120.642706          45883    380.321376              89641
#
#        FlowReceivedRate  PacketLengthVariance  PacketLengthStandardDeviation  \
# 0            687.388878           7474.676771                      86.456213
# 1            827.672018          10458.118600                     102.264943
# 2            316.108645           7300.293933                      85.441758
# 3            631.278898           8499.282518                      92.191553
# 4           1416.266907           8052.745751                      89.737092
# ...                 ...                   ...                            ...
# 39609        328.045920          40999.197040                     202.482585
# 39610        266.174198          24846.903090                     157.629005
# 39611        732.521636          33856.106820                     184.000290
# 39612        717.436675          33823.060610                     183.910469
# 39613        743.028758          33324.590930                     182.550242
#
#        PacketLengthMean  PacketLengthMedian  PacketLengthMode  ...  \
# 0            135.673751               102.0                54  ...
# 1            141.245474               114.0                54  ...
# 2            133.715278                89.0                54  ...
# 3            139.123548               114.0                54  ...
# 4            138.913420               114.0               114  ...
# ...                 ...                 ...               ...  ...
# 39609        168.915119               148.0                68  ...
# 39610        195.132867               180.0                68  ...
# 39611        243.017857               257.0                68  ...
# 39612        250.015209               257.0                68  ...
# 39613        258.633588               257.0                68  ...
#
#        PacketTimeMode  PacketTimeSkewFromMedian  PacketTimeSkewFromMode  \
# 0            1.495060                 -0.433974                1.682529
# 1           31.719656                  0.389704                0.772748
# 2            0.417528                  0.858198                1.353607
# 3           13.280934                  1.508251                1.148758
# 4            7.342519                 -2.172613                1.573873
# ...               ...                       ...                     ...
# 39609        0.000000                  0.250039                1.479948
# 39610        0.000000                 -0.647442                1.942514
# 39611        0.000000                 -0.195235                1.756956
# 39612        0.000000                 -0.089359                1.733606
# 39613        0.000000                  0.059454                1.679092
#
#        PacketTimeCoefficientofVariation  ResponseTimeTimeVariance  \
# 0                              0.574626                  0.001053
# 1                              0.509047                  0.001170
# 2                              0.732636                  0.000785
# 3                              0.646859                  0.000411
# 4                              0.507334                  0.079079
# ...                                 ...                       ...
# 39609                          0.675699                  0.104322
# 39610                          0.514797                  0.179608
# 39611                          0.569166                  0.027457
# 39612                          0.576832                  0.032776
# 39613                          0.595560                  0.015896
#
#        ResponseTimeTimeStandardDeviation  ResponseTimeTimeMean  \
# 0                               0.032457              0.027624
# 1                               0.034200              0.024387
# 2                               0.028021              0.029238
# 3                               0.020274              0.019925
# 4                               0.281209              0.025930
# ...                                  ...                   ...
# 39609                           0.322989              0.184579
# 39610                           0.423802              0.259088
# 39611                           0.165701              0.091486
# 39612                           0.181041              0.090967
# 39613                           0.126080              0.062919
#
#        ResponseTimeTimeMode  ResponseTimeTimeSkewFromMode  \
# 0                  0.026822                      0.024715
# 1                  0.026981                     -0.075845
# 2                  0.026855                      0.085061
# 3                  0.026918                     -0.344926
# 4                  0.000021                      0.092135
# ...                     ...                           ...
# 39609              0.026358                      0.489865
# 39610              0.000017                      0.611301
# 39611              0.026402                      0.392777
# 39612              0.026442                      0.356412
# 39613              0.026410                      0.289569
#
#        ResponseTimeTimeCoefficientofVariation
# 0                                    1.174948
# 1                                    1.402382
# 2                                    0.958348
# 3                                    1.017535
# 4                                   10.844829
# ...                                       ...
# 39609                                1.749867
# 39610                                1.635747
# 39611                                1.811224
# 39612                                1.990176
# 39613                                2.003853
#
# [39614 rows x 27 columns]

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 39609    1
# 39610    1
# 39611    1
# 39612    1
# 39613    1
# Name: Label, Length: 39614, dtype: int64

# %% [markdown]
# Data preprocessing

# %%
X.isnull().sum()
# Out:
# Duration                                  0
# FlowBytesSent                             0
# FlowSentRate                              0
# FlowBytesReceived                         0
# FlowReceivedRate                          0
# PacketLengthVariance                      0
# PacketLengthStandardDeviation             0
# PacketLengthMean                          0
# PacketLengthMedian                        0
# PacketLengthMode                          0
# PacketLengthSkewFromMedian                0
# PacketLengthSkewFromMode                  0
# PacketLengthCoefficientofVariation        0
# PacketTimeVariance                        0
# PacketTimeStandardDeviation               0
# PacketTimeMean                            0
# PacketTimeMedian                          0
# PacketTimeMode                            0
# PacketTimeSkewFromMedian                  0
# PacketTimeSkewFromMode                    0
# PacketTimeCoefficientofVariation          0
# ResponseTimeTimeVariance                  0
# ResponseTimeTimeStandardDeviation         0
# ResponseTimeTimeMean                      0
# ResponseTimeTimeMode                      0
# ResponseTimeTimeSkewFromMode              0
# ResponseTimeTimeCoefficientofVariation    0
# dtype: int64

# %%
X=X.dropna()

# %% [markdown]
# Dataset split

# %%
from sklearn.preprocessing import StandardScaler

std = StandardScaler()

# %%
std.fit(X)

# 학습 데이터 스케일링
X_scaled = std.transform(X)
X = X_scaled

# %%
X
# Out:
# array([[ 0.91082026,  0.07800172, -0.1105849 , ..., -0.11113174,
#          0.02988006,  0.00529606],
#        [ 1.4318847 ,  0.26557253, -0.11031832, ..., -0.11104515,
#         -0.00160916,  0.12070614],
#        [ 1.4060321 , -0.06201726, -0.11138301, ..., -0.11111377,
#          0.04877682, -0.10461618],
#        ...,
#        [ 1.39459831, -0.00762726, -0.11119816, ..., -0.11136047,
#          0.14513459,  0.32817074],
#        [ 1.39933677, -0.02514824, -0.11125831, ..., -0.11133869,
#          0.13374734,  0.41897873],
#        [ 1.39999034, -0.01976815, -0.1112407 , ..., -0.11135612,
#          0.11281607,  0.42591892]])

# %%
X.shape
# Out:
# (39614, 27)

# %% [markdown]
# ## Pearson correlation

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(20,20))
cor = df.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
cor_target = abs(cor['Label'])

# %%
relevant_features = cor_target[cor_target>0.3]
relevant_features
# Out:
# PacketLengthStandardDeviation         0.391646
# PacketLengthMean                      0.373630
# PacketLengthCoefficientofVariation    0.444325
# PacketTimeSkewFromMedian              0.319793
# Label                                 1.000000
# Name: Label, dtype: float64

# %%
relevant_features.index
# Out:
# Index(['PacketLengthStandardDeviation', 'PacketLengthMean',
#        'PacketLengthCoefficientofVariation', 'PacketTimeSkewFromMedian',
#        'Label'],
#       dtype='object')

# %%
index = []
for i in range(len(relevant_features)):
    index.append(relevant_features.index[i])

# %%
index
# Out:
# ['PacketLengthStandardDeviation',
#  'PacketLengthMean',
#  'PacketLengthCoefficientofVariation',
#  'PacketTimeSkewFromMedian',
#  'Label']

# %%
len(index)
# Out:
# 5

# %%
index =index[:-1]

# %%
new_x = df[index]

# %%
new_x
# Out:
#        PacketLengthStandardDeviation  PacketLengthMean  \
# 0                          86.456213        135.673751
# 1                         102.264943        141.245474
# 2                          85.441758        133.715278
# 3                          92.191553        139.123548
# 4                          89.737092        138.913420
# ...                              ...               ...
# 39609                     202.482585        168.915119
# 39610                     157.629005        195.132867
# 39611                     184.000290        243.017857
# 39612                     183.910469        250.015209
# 39613                     182.550242        258.633588
#
#        PacketLengthCoefficientofVariation  PacketTimeSkewFromMedian
# 0                                0.637236                 -0.433974
# 1                                0.724023                  0.389704
# 2                                0.638983                  0.858198
# 3                                0.662660                  1.508251
# 4                                0.645993                 -2.172613
# ...                                   ...                       ...
# 39609                            1.198724                  0.250039
# 39610                            0.807803                 -0.647442
# 39611                            0.757147                 -0.195235
# 39612                            0.735597                 -0.089359
# 39613                            0.705826                  0.059454
#
# [39614 rows x 4 columns]

# %%
from sklearn.preprocessing import StandardScaler

std = StandardScaler()

# %%
std.fit(new_x)

# 학습 데이터 스케일링
X_scaled = std.transform(new_x)
X = X_scaled

# %%
X
# Out:
# array([[-0.58998661, -0.39496541, -0.4836825 , -0.46480607],
#        [-0.51268833, -0.32923212, -0.35176936,  0.14718015],
#        [-0.59494689, -0.41807081, -0.48102763,  0.4952671 ],
#        ...,
#        [-0.11303561,  0.8714438 , -0.30142126, -0.28742508],
#        [-0.1134748 ,  0.95399618, -0.33417673, -0.20876019],
#        [-0.12012575,  1.05567287, -0.37942834, -0.09819289]])

# %%
#train:validation:test = 6:2:2

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=10)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 0.2, random_state=10)

# %%
X_train
# Out:
# array([[-0.92282835, -0.91021345, -1.14851966, -1.71439087],
#        [-0.29883161, -0.01853039, -0.12801754, -0.47037973],
#        [-0.55527478, -0.46224024, -0.3581651 , -0.07337432],
#        ...,
#        [ 1.68156759,  2.05467193,  0.98733606, -0.22104031],
#        [-0.90823604, -1.19807634, -0.9717822 ,  0.97264904],
#        [ 0.85251772,  0.703625  ,  1.08201389,  1.24493861]])

# %%
y_train
# Out:
# 1309     0
# 39338    1
# 23411    1
# 33723    1
# 30357    1
#         ..
# 9624     0
# 25334    1
# 31011    1
# 15594    0
# 32585    1
# Name: Label, Length: 25352, dtype: int64

# %% [markdown]
# pilot Logistic Regression

# %%
from sklearn import datasets
import numpy as np
import pandas as pd
import sklearn
from sklearn.linear_model import LogisticRegression

# %%
#모델 만들기
model = LogisticRegression(class_weight='balanced')

param_grid = {'C': [1, 10, 100, 1000]}
clf = sklearn.model_selection.GridSearchCV(model, param_grid)

# 모델 학습
model = model.fit(X_train, y_train)

# %%
# 학습시킨 모델에 test
predictions = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score

print("accuracy: ", accuracy_score(y_test, predictions))
print("recall: ", recall_score(y_test, predictions, zero_division=1))
print("precision: ", precision_score(y_test, predictions, zero_division=1))
print("f1 score: " ,f1_score(y_test, predictions,  average='weighted'))
# Out:
# accuracy:  0.6765114224409946
# recall:  0.6771594056912617
# precision:  0.6773299748110831
# f1 score:  0.6765115151996371
