# %%
import pandas as pd
df = pd.read_csv('./mu1/CIRA_no-sampling_train_noise.csv')
df = df.drop(['Unnamed: 0','Label'], axis=1)
df
# Out:
#         Duration  FlowBytesSent  FlowSentRate  FlowBytesReceived  \
# 0       8.070250   16861.937761   5422.713693       24307.991947
# 1      38.927396    4746.020472    144.356632        7663.927474
# 2       5.089800     175.918764   2483.362617         176.143478
# 3      20.081088   65707.934378   4386.341281      112544.120451
# 4       5.077230     331.947403  21097.727697         131.026874
# ...          ...            ...           ...                ...
# 23763   5.109937     969.007479  10620.188199        3571.897209
# 23764   5.097497    1037.001193   9433.384440        3640.106859
# 23765  39.018401    1811.896720     57.958858        4901.105657
# 23766   9.342640     357.920061     87.190391         332.217687
# 23767   8.191609    5259.982110   1695.871673        3307.932637
#
#        FlowReceivedRate  PacketLengthVariance  PacketLengthStandardDeviation  \
# 0           7815.939378          17571.589324                     137.470205
# ...

# %%
import pandas as pd
no_noise = pd.read_csv('../without_sampling/CIRA_train.csv')
no_noise = no_noise.drop(['Unnamed: 0','ResponseTimeTimeMedian','ResponseTimeTimeSkewFromMedian', 'Label'], axis=1)
no_noise
# Out:
#         Duration  FlowBytesSent  FlowSentRate  FlowBytesReceived  \
# 0       3.111414          16857   5417.793968              24303
# 1      34.037245           4741    139.288594               7659
# 2       0.069001            171   2478.224953                171
# 3      14.995403          65703   4381.542797             112539
# 4       0.015503            327  21092.691740                126
# ...          ...            ...           ...                ...
# 23763   0.090814            964  10615.103400               3567
# 23764   0.109456           1032   9428.446134               3635
# 23765  34.075047           1807     53.030008               4896
# 23766   4.298531            353     82.121078                327
# 23767   3.108167           5255   1690.707095               3303
#
#        FlowReceivedRate  PacketLengthVariance  PacketLengthStandardDeviation  \
# 0           7810.918123          17566.450570                     132.538487
# ...

# %%
diff = df - no_noise

# %%
description = diff.describe()
description
# Out:
#            Duration  FlowBytesSent  FlowSentRate  FlowBytesReceived  \
# count  23768.000000   23768.000000  23768.000000       23768.000000
# mean       5.000366       5.000136      5.000650           5.000074
# std        0.099954       0.099464      0.099582           0.100130
# min        4.610512       4.609731      4.607718           4.609086
# 25%        4.932764       4.932789      4.933345           4.932635
# 50%        5.000070       4.999864      5.001364           5.000445
# 75%        5.067275       5.066797      5.067900           5.067988
# max        5.434976       5.428982      5.432758           5.415092
#
#        FlowReceivedRate  PacketLengthVariance  PacketLengthStandardDeviation  \
# count      23768.000000          23768.000000                   23768.000000
# mean           5.000447              5.001221                       5.000277
# std            0.099817              0.099408                       0.100570
# ...

# %%
mean_series = description.iloc[1]
mean_series
# Out:
# Duration                                  5.000366
# FlowBytesSent                             5.000136
# FlowSentRate                              5.000650
# FlowBytesReceived                         5.000074
# FlowReceivedRate                          5.000447
# PacketLengthVariance                      5.001221
# PacketLengthStandardDeviation             5.000277
# PacketLengthMean                          4.999510
# PacketLengthMedian                        4.998984
# PacketLengthMode                          5.000706
# PacketLengthSkewFromMedian                5.000642
# PacketLengthSkewFromMode                  4.999872
# PacketLengthCoefficientofVariation        4.999365
# PacketTimeVariance                        5.000641
# PacketTimeStandardDeviation               4.999651
# PacketTimeMean                            5.000143
# PacketTimeMedian                          5.000399
# PacketTimeMode                            4.999561
# ...

# %%
mean_series.mean()
# Out:
# 5.000077231519692
